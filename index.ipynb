# %% [markdown]
# ### Alien Biology Module.
#
# Hello. Here our biologists have assembled some models that might help in your research. Follow the instructions below to complete the necessary research into these mysterious beings.

# %% [markdown]
# ### Tier 1. Understanding Alien Genetics.
#
# OUTCOME: DETERMINE, FOR THREE DIFFERENT CHARACTERISTICS, WHICH TRAITS ARE DOMINANT, RECESSIVE, OR PARTIALLY DOMINANT. ALSO IDENTIFY THE ALLELE SETS FOR EACH OF THREE PARENT GROUPS.
#
# Several traits are relevant when designing the cockpit interfaces for these alien pilots. Our engineers have asked us to consider 3.
#
# First, we consider finger lengths of the aliens. These aliens have finger characteristics that fall into three categories: 1) fingers of equal length, about 30 cm, 2) fingers of different lengths ranging from 20 to 45 cm, and 3) hand structures with 2 fingers of equal length and 2 fingers of varying length, which we denote as "partially equal."
#
# Second, we consider the ability of these aliens to see light at wavelengths different from our own. A significant portion of the alien population can see light within the infrared range, which is useful in detecting several toxic chemicals on their homeworld. However, over the last several millenia, a mutation has introduced a gene that has shifted some alien visual ability into the ultraviolet spectrum, which has its uses in detecting light from certain bioluminescent sources. However, these traits appear mutually exlusive. Thus two traits are governed by these alleles: 1) infrared vision ability, and 2) UV vision ability.
#
# Finally, we consider neck length, which has ergonomic importance. The two possible displayed traits are 1) a longer neck (about 30 cm in length) and 2) a shorter neck (about 15 cm in length). These lengths appear to also be governed by a pair of alleles.
#
# Your task: For each of the three characteristics described above, determine which traits are dominant, recessive, and in the case of finger length, partially dominant. Several of your biologists are currently studying several alien "broods" on the planet, large collections of several hundred children born to a pair of parents. These biologists can tell you which traits are displayed by the parents, and then how many of their children display each of the traits in the brood. Using this information and your understanding of genetic inheritance, attempt to identify which traits are dominant, recessive, or partially dominant. Also identfy the alleles possesed by each of the parents.
#
# #### Family Descriptions:
#
# FAMILY 1: The father displays partially equally sized fingers, infrared vision, and a long neck. The mother displays equally sized fingers, infrared vision, and a short neck.
#
# FAMILY 2: The father displays different sized fingers, UV vision, and a long neck. The mother displays equally sized fingers, infrared vision, and a long neck.
#
# FAMILY 3: The father displays equally sized fingers, UV vision, and a short neck. The mother displays equally sized fingers, UV vision, and a long neck.
#
# Simply input which family (1,2, or 3) you wish to study in the code below and click "Run Cell."

# %%
'''
Ignore this section, our biologists are simply 
loading in helpful tools for this analysis.
'''
import numpy as np
import matplotlib.pyplot as plt
from biocalls import *
np.random.seed(123)
# %matplotlib inline

'''
Here, enter which family (1, 2, or 3) you would like to
have your biologists gather data for in this trial.
You only need to input the number.
'''
family = 2


print 'Request Sent...'
alienGenetics1(family)

# %% [markdown]
# ### Tier 2. Generating a strategy to select for desired traits.
#
# Now that we have a better understanding of the genetics involved in this project, our biologists have been asked to recommend "breeding strategies" that the alien brood organizers may use to breed pilots that are best suited for duty. This also has the effect of narrowing the traits our engineers must design for when building the cockpit.
#
# OUTCOME: Propose THREE DIFFERENT breeding strategies to meet the following goals:
#
# 1) Maximize the children with partially equal length fingers in the second generation, and minimize the short neck offspring in the second generation.
#
# 2) Minimize the children with different length fingers, while achieving a 50/50 distribution of children with Infrared/UV vision capabilities.
#
# 3) Maximize the children with different length fingers, while maximizing the children with UV visual abilities and also maximizing the children with long necks.
#
# These plans involve three components you must specify:
#
# 1) Select the DISPLAYED FEATURES for both of the original parents, the original father and mother. Note that the selection may be specified in the cell below as follows:
#
# 'F' is the dominant finger trait (identified in Tier 1 research),
#
# 'f' is the recessive finger trait,
#
# 'Ff' is the partially dominant finger trait,
#
# 'V' is the dominant vision trait,
#
# 'v' is the recessive vision trait,
#
# 'N' is the dominant neck length trait, and
#
# 'n' is the recessive neck length trait.
#
# 2) The DISPLAYED FEATURES for a second-generation parent. This parent will mate with an offspring of the original two parents.
#
# 3) A SINGER DISPLAYED FEATURE the first-generation child must have to be allowed to mate with the second-generation parent. This child will then have the chosen trait, with the others inherited from the original parents, and will mate with the parent specified in step (2) to create the final generation.
#
# To assist you, our biologists have prepared a simulation that, given your choices above, will display histograms of the likely traits displayed in a child in the second generation. Compare these results to your goals for each strategy when making final selections. ASK A COMMANDER IF YOU NEED HELP OR DO NOT UNDERSTAND SOMETHING.

# %%
'''
Ignore this section, our biologists are simply 
loading in helpful tools for this analysis.
'''
import numpy as np
import matplotlib.pyplot as plt
from biocalls import *
np.random.seed(123)
# %matplotlib inline

'''
Below, input the displayed traits for the first generation mother and father,
the traits for the second generation additional parent, and the necessary 
mating trait for the first generation offspring. Click "run" to run the model
and get predictions on the traits of the second generation.
'''

# the traits here are filled in as an example.
# change traits with the values given in the description.
# make sure you keep the order as given.
father_1 = [ 'F','V','N' ]
mother_1 = [ 'f', 'v', 'N' ]
additional_parent = ['f','v','N']
child_necessary_trait = 'Ff'

alienGenetics2(father_1,mother_1,additional_parent,child_necessary_trait)
